# %% [markdown]
# # Kaggle template: credit-card fraud
#
# This notebook is intentionally clean: it assumes you downloaded `creditcard.csv` from Kaggle and placed it under `examples_external/data/creditcard.csv`. External data is optional and not part of the test suite.

# %%
from pathlib import Path
import pandas as pd

path = Path("examples_external/data/creditcard.csv")
assert path.exists(), "Download creditcard.csv first."
df = pd.read_csv(path)
print(df.shape)
print(df["Class"].value_counts())

# %%
# Run the packaged external script from a notebook cell.
# In a Kaggle notebook, replace paths with /kaggle/input/... and /kaggle/working/...
# !python examples_external/kaggle_credit_card_fraud.py   --data examples_external/data/creditcard.csv   --outdir results/external/credit_card_fraud

# %%
pd.read_csv("results/external/credit_card_fraud/metrics.csv")

# %% [markdown]
# The documented result should be read honestly: this dataset is a strong robustcov result, but runtime and thresholding budget should always be reported.
