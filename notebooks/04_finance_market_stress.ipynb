# %% [markdown]
# # Finance market-stress detection
#
# This notebook uses a local price table and robust distances to identify unusual multivariate market days and rolling windows.

# %%
from pathlib import Path
import pandas as pd

prices = Path("examples_external/data/prices.csv")
assert prices.exists(), "Run examples_external/make_synthetic_prices.py or provide a prices.csv file."
pd.read_csv(prices).head()

# %%
# !python examples_external/finance_market_stress.py   --prices examples_external/data/prices.csv   --outdir results/external/finance_market_stress

# %%
# !python examples_external/finance_rolling_window_anomaly.py   --prices examples_external/data/prices.csv   --window 20   --step 5   --outdir results/external/finance_rolling_window

# %%
pd.read_csv("results/external/finance_market_stress/stress_days.csv").head(10)

# %% [markdown]
# The finance examples are best understood as interpretable risk diagnostics, not supervised prediction benchmarks.
